# %% [markdown]
# Load Data

# %% [markdown]
# Number of Images

# %% [markdown]
# Data Balance

# %% [markdown]
# Plotting Image Sizes

# %% [markdown]
# #Viewing a Sampling of Images

# %% [markdown]
# Data Preparation

# %% [markdown]
# Feature Engineering

# %% [markdown]
# Configure the dataset for performance

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

# 1. Set up paths and load data
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Set up paths
base_dir = '/content/drive/My Drive/data/data'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File loaded successfully!
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 101, 101, 32)        │           1,760 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 50, 50, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 50, 50, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 25, 25, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 25, 25, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 40000)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │       2,560,064 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,617,313 (9.98 MB)
#  Trainable params: 2,617,313 (9.98 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 30s 719ms/step - accuracy: 0.5885 - loss: 0.8723 - val_accuracy: 0.6500 - val_loss: 0.6516
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 726ms/step - accuracy: 0.6624 - loss: 0.6477 - val_accuracy: 0.6500 - val_loss: 0.6543
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 744ms/step - accuracy: 0.6624 - loss: 0.6433 - val_accuracy: 0.6500 - val_loss: 0.6575
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 25s 658ms/step - accuracy: 0.6624 - loss: 0.6437 - val_accuracy: 0.6500 - val_loss: 0.6527
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 736ms/step - accuracy: 0.6624 - loss: 0.6420 - val_accuracy: 0.6500 - val_loss: 0.6510
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 737ms/step - accuracy: 0.6624 - loss: 0.6399 - val_accuracy: 0.6500 - val_loss: 0.6516
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 35s 937ms/step - accuracy: 0.6624 - loss: 0.6370 - val_accuracy: 0.6500 - val_loss: 0.6665
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 34s 734ms/step - accuracy: 0.6624 - loss: 0.6335 - val_accuracy: 0.6500 - val_loss: 0.7561
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 715ms/step - accuracy: 0.6613 - loss: 0.6487 - val_accuracy: 0.6500 - val_loss: 0.7523
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 665ms/step - accuracy: 0.6629 - loss: 0.6313 - val_accuracy: 0.6500 - val_loss: 0.7163
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 711ms/step - accuracy: 0.6730 - loss: 0.6080 - val_accuracy: 0.6400 - val_loss: 0.6755
# Epoch 12/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 706ms/step - accuracy: 0.6695 - loss: 0.5871 - val_accuracy: 0.6400 - val_loss: 0.7071
# Epoch 13/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 38s 635ms/step - accuracy: 0.6946 - loss: 0.5839 - val_accuracy: 0.6100 - val_loss: 0.7608
# Epoch 14/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 688ms/step - accuracy: 0.7037 - loss: 0.5500 - val_accuracy: 0.5967 - val_loss: 0.8561
# Epoch 15/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 723ms/step - accuracy: 0.7510 - loss: 0.5128 - val_accuracy: 0.6067 - val_loss: 0.9411
# Epoch 16/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 739ms/step - accuracy: 0.7941 - loss: 0.4420 - val_accuracy: 0.6167 - val_loss: 1.0983
# Epoch 17/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 25s 667ms/step - accuracy: 0.8570 - loss: 0.3287 - val_accuracy: 0.5633 - val_loss: 0.9495
# Epoch 18/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 673ms/step - accuracy: 0.8914 - loss: 0.2587 - val_accuracy: 0.5533 - val_loss: 1.1416
# Epoch 19/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 726ms/step - accuracy: 0.9141 - loss: 0.2382 - val_accuracy: 0.5467 - val_loss: 2.1560
# Epoch 20/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 25s 672ms/step - accuracy: 0.9094 - loss: 0.2382 - val_accuracy: 0.5700 - val_loss: 2.0400
# Epoch 21/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 697ms/step - accuracy: 0.9546 - loss: 0.1336 - val_accuracy: 0.5800 - val_loss: 2.8354
# Epoch 22/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 709ms/step - accuracy: 0.9764 - loss: 0.0871 - val_accuracy: 0.5733 - val_loss: 3.3864
# Epoch 23/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 712ms/step - accuracy: 0.9734 - loss: 0.0769 - val_accuracy: 0.5500 - val_loss: 2.2977
# Epoch 24/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 672ms/step - accuracy: 0.9790 - loss: 0.0697 - val_accuracy: 0.5400 - val_loss: 1.9412
# Epoch 25/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 821ms/step - accuracy: 0.9868 - loss: 0.0411 - val_accuracy: 0.5333 - val_loss: 2.8027
# Epoch 26/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 735ms/step - accuracy: 0.9961 - loss: 0.0153 - val_accuracy: 0.5433 - val_loss: 2.6114
# Epoch 27/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 716ms/step - accuracy: 0.9976 - loss: 0.0128 - val_accuracy: 0.5300 - val_loss: 2.8734
# Epoch 28/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 39s 669ms/step - accuracy: 0.9975 - loss: 0.0114 - val_accuracy: 0.5367 - val_loss: 2.7925
# Epoch 29/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 695ms/step - accuracy: 0.9977 - loss: 0.0118 - val_accuracy: 0.5333 - val_loss: 2.8723
# Epoch 30/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 711ms/step - accuracy: 0.9976 - loss: 0.0096 - val_accuracy: 0.5333 - val_loss: 2.8245
# Epoch 31/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 25s 671ms/step - accuracy: 0.9977 - loss: 0.0095 - val_accuracy: 0.5367 - val_loss: 2.9272
# Epoch 32/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 714ms/step - accuracy: 0.9976 - loss: 0.0089 - val_accuracy: 0.5333 - val_loss: 2.8342
# Epoch 33/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 736ms/step - accuracy: 0.9977 - loss: 0.0089 - val_accuracy: 0.5367 - val_loss: 2.9001
# Epoch 34/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 753ms/step - accuracy: 0.9981 - loss: 0.0117 - val_accuracy: 0.5300 - val_loss: 2.6821
# Epoch 35/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 712ms/step - accuracy: 0.9977 - loss: 0.0079 - val_accuracy: 0.5233 - val_loss: 2.8622
# Epoch 36/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 685ms/step - accuracy: 0.9976 - loss: 0.0093 - val_accuracy: 0.5300 - val_loss: 2.7539
# Epoch 37/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 691ms/step - accuracy: 0.9977 - loss: 0.0076 - val_accuracy: 0.5233 - val_loss: 2.8301
# Epoch 38/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 737ms/step - accuracy: 0.9976 - loss: 0.0083 - val_accuracy: 0.5300 - val_loss: 2.7682
# Epoch 39/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 718ms/step - accuracy: 0.9977 - loss: 0.0075 - val_accuracy: 0.5333 - val_loss: 2.8096
# Epoch 40/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 39s 674ms/step - accuracy: 0.9976 - loss: 0.0078 - val_accuracy: 0.5300 - val_loss: 2.7525
# Epoch 41/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 655ms/step - accuracy: 0.9977 - loss: 0.0068 - val_accuracy: 0.5367 - val_loss: 2.8768
# Epoch 42/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 716ms/step - accuracy: 0.9976 - loss: 0.0089 - val_accuracy: 0.5300 - val_loss: 2.6666
# Epoch 43/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 724ms/step - accuracy: 0.9977 - loss: 0.0065 - val_accuracy: 0.5333 - val_loss: 2.8561
# Epoch 44/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 734ms/step - accuracy: 0.9976 - loss: 0.0077 - val_accuracy: 0.5333 - val_loss: 2.7458
# Epoch 45/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 693ms/step - accuracy: 0.9977 - loss: 0.0065 - val_accuracy: 0.5300 - val_loss: 2.7853
# Epoch 46/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 718ms/step - accuracy: 0.9976 - loss: 0.0072 - val_accuracy: 0.5400 - val_loss: 2.6959
# Epoch 47/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 728ms/step - accuracy: 0.9977 - loss: 0.0063 - val_accuracy: 0.5367 - val_loss: 2.7952
# Epoch 48/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 697ms/step - accuracy: 0.9976 - loss: 0.0070 - val_accuracy: 0.5367 - val_loss: 2.7247
# Epoch 49/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 682ms/step - accuracy: 0.9977 - loss: 0.0061 - val_accuracy: 0.5400 - val_loss: 2.7847
# Epoch 50/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 721ms/step - accuracy: 0.9976 - loss: 0.0065 - val_accuracy: 0.5400 - val_loss: 2.7552
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.5689 - loss: 2.7175
# Validation Accuracy: 0.5400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step
# Confusion Matrix:
# [[135  60]
#  [ 78  27]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.69      0.66       195
#          1.0       0.31      0.26      0.28       105
#
#     accuracy                           0.54       300
#    macro avg       0.47      0.47      0.47       300
# weighted avg       0.52      0.54      0.53       300
#
# ROC AUC Score: 0.4687
# Model saved successfully.

# %%
train_dir = os.path.join(base_dir, "training")
train_labels_file = os.path.join(base_dir, "labels_training.csv")

# Check if the file exists
if not os.path.exists(train_labels_file):
    print(f"Error: The file {train_labels_file} does not exist.")
else:
    # Load Data
    train_labels_df = pd.read_csv(train_labels_file)
    print("File loaded successfully!")

# Load labels
train_labels_df = pd.read_csv(train_labels_file)

# 2. Prepare file paths and labels
image_files = [os.path.join(train_dir, f) for f in os.listdir(train_dir) if f.endswith('.tif')]
labels = train_labels_df['label'].values

# 3. Split data into training and validation sets (80% train, 20% validation)
train_files, val_files, train_labels, val_labels = train_test_split(
    image_files, labels, test_size=0.2, random_state=42
)

# 4. Define data loading and preprocessing function
def load_and_preprocess_image(file_path):
    # Load and preprocess the image
    with Image.open(file_path) as img:
        img = img.convert('RGB').resize((101, 101))
        img_array = np.array(img).astype(np.float32) / 255.0

    # Create additional features
    grayscale = np.mean(img_array, axis=-1, keepdims=True)
    dx, dy = np.gradient(grayscale[:,:,0])
    edge_magnitude = np.sqrt(dx**2 + dy**2)
    texture = np.abs(grayscale - np.mean(grayscale))

    # Combine all features
    features = np.concatenate([img_array, grayscale, edge_magnitude[..., np.newaxis], texture], axis=-1)
    return features

# 5. Prepare datasets
def prepare_dataset(file_paths, labels):
    images = [load_and_preprocess_image(file_path) for file_path in file_paths]
    dataset = tf.data.Dataset.from_tensor_slices((np.array(images), np.array(labels, dtype=np.float32)))
    return dataset.batch(32).prefetch(tf.data.AUTOTUNE)

train_dataset = prepare_dataset(train_files, train_labels)
val_dataset = prepare_dataset(val_files, val_labels)

# 6. Create the model
def create_model():
    model = models.Sequential([
        layers.Input(shape=(101, 101, 6)),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    return model

# Create and compile the model
model = create_model()
model.compile(optimizer=optimizers.Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()

# 7. Train the model
history = model.fit(train_dataset, epochs=50, validation_data=val_dataset)

# 8. Evaluate the model
val_loss, val_accuracy = model.evaluate(val_dataset)
print(f"Validation Accuracy: {val_accuracy:.4f}")

# 9. Make predictions on validation set
val_predictions = model.predict(val_dataset)

# 10. Visualize predictions vs actual values
val_labels_array = np.concatenate([labels for _, labels in val_dataset])
val_predictions_flat = val_predictions.flatten()

# Sort the data points by actual values for a cleaner line plot
sorted_indices = np.argsort(val_labels_array)
sorted_actual = val_labels_array[sorted_indices]
sorted_predicted = val_predictions_flat[sorted_indices]

plt.figure(figsize=(12, 6))

# Plot actual values
plt.plot(range(len(sorted_actual)), sorted_actual, label='Actual Values', color='blue')

# Plot predicted probabilities
plt.plot(range(len(sorted_predicted)), sorted_predicted, label='Predicted Probabilities', color='red', alpha=0.7)

# Add decision boundary
plt.axhline(y=0.5, color='green', linestyle='--', label='Decision Boundary')

plt.xlabel('Samples (sorted by actual value)')
plt.ylabel('Values / Probabilities')
plt.title('Predictions vs Actual Values on Validation Set')
plt.legend()
plt.tight_layout()
plt.show()

# Optional: You can also add a second plot to show the difference
plt.figure(figsize=(12, 6))
plt.plot(range(len(sorted_actual)), sorted_predicted - sorted_actual, color='purple')
plt.axhline(y=0, color='black', linestyle='--')
plt.xlabel('Samples (sorted by actual value)')
plt.ylabel('Prediction Error (Predicted - Actual)')
plt.title('Prediction Error on Validation Set')
plt.tight_layout()
plt.show()

# 11. Calculate and print confusion matrix and classification report
val_predictions_binary = (val_predictions > 0.5).astype(int)
cm = confusion_matrix(val_labels_array, val_predictions_binary)
print("Confusion Matrix:")
print(cm)
print("\nClassification Report:")
print(classification_report(val_labels_array, val_predictions_binary))

# 12. Calculate and print ROC AUC score
roc_auc = roc_auc_score(val_labels_array, val_predictions)
print(f"ROC AUC Score: {roc_auc:.4f}")

# 13. Save the model
model.save('solar_panel_detection_model.keras')
print("Model saved successfully.")

# %%
import os
import pandas as pd
import pickle

# Mount Google Drive (if using Google Colab)
from google.colab import drive
drive.mount('/content/drive')

# Set up paths
base_dir = '/content/drive/My Drive/data/data'
train_labels_file = os.path.join(base_dir, "labels_training.csv")

# Check if the file exists
if not os.path.exists(train_labels_file):
    print(f"Error: The file {train_labels_file} does not exist.")
else:
    # Load Data
    train_labels_df = pd.read_csv(train_labels_file)
    print("File loaded successfully!")

# Assuming `model` is your already trained model
# 1. Save the Keras model
keras_file_name = 'solar_panel_detection_model.keras'
keras_file_path = os.path.join(base_dir, keras_file_name)

# Save the model to a Keras file
model.save(keras_file_path)
print(f"Keras model was successfully saved to '{keras_file_path}'")

# 2. Save the model as a pickle file
pickle_file_name = 'solar_panel_detection_model.pkl'
pickle_file_path = os.path.join(base_dir, pickle_file_name)

# Save the model to a pickle file
with open(pickle_file_path, 'wb') as file:
    pickle.dump(model, file)
    print(f"Pickle file was successfully saved to '{pickle_file_path}'")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File loaded successfully!
# Keras model was successfully saved to '/content/drive/My Drive/data/data/solar_panel_detection_model.keras'
# Pickle file was successfully saved to '/content/drive/My Drive/data/data/solar_panel_detection_model.pkl'
